# %% [markdown]
# # Project I Part 1

# %% [markdown]
# ### 1. จงเขียนโปรแกรมรับค่า Input จากผู้ใช้ ถ้าผู้ใช้ใส่ 0.0 จึงจะสิ้นสุดโปรแกรม คำนวณหาค่าเฉลี่ยของเลขทั้งหมดที่ผู้ใช้ใส่     และปริ้นค่าเฉลี่ยคูณด้วยจำนวนครั้งที่ใส่ทั้งหมด

# %%
lst = []
while True:
    x = input("จงป้อนตัวเลขที่คุณต้องการหาค่าเฉลี่ย (ป้อน 0.0 เพื่อออก): ")
    if x == "0.0":
        break
    lst.append(int(x))
avg = sum(lst)/len(lst)
print("ค่าเฉลี่ยของจำนวนทั้งหมดคือ " + str(avg))
# Out:
# จงป้อนตัวเลขที่คุณต้องการหาค่าเฉลี่ย (ป้อน 0.0 เพื่อออก): 10
# จงป้อนตัวเลขที่คุณต้องการหาค่าเฉลี่ย (ป้อน 0.0 เพื่อออก): 20
# จงป้อนตัวเลขที่คุณต้องการหาค่าเฉลี่ย (ป้อน 0.0 เพื่อออก): 30
# จงป้อนตัวเลขที่คุณต้องการหาค่าเฉลี่ย (ป้อน 0.0 เพื่อออก): 0.0
# ค่าเฉลี่ยของจำนวนทั้งหมดคือ 20.0

# %% [markdown]
# ### 2. จงเขียนโปรแกรมให้ผู้ใช้ใส่เลข ขอบเขตล่าง และ ขอบเขตบน และคำนวณหาเลขจำนวนเฉพาะ (Prime Number) ที่อยู่ระหว่างขอบเขตล่างและขอบเขตบน

# %%
lower = int(input("กรุณาป้อนขอบเขตล่าง: "))
upper = int(input("กรุณาป้อนขอบเขตบน: "))
for num in range(lower, upper + 1):
    if num > 1:
        for i in range(2, num):
            if (num % i) == 0:
                break
        else:
            print(num)
# Out:
# กรุณาป้อนขอบเขตล่าง: 10
# กรุณาป้อนขอบเขตบน: 20
# 11
# 13
# 17
# 19

# %% [markdown]
# # Project I Part 2

# %% [markdown]
# ## วิเคราะห์ข้อมูลจากยอดขายของวิดีโอเกมส์ จากกว่า 16,500 เกมส์

# %% [markdown]
# ### 1. Import ไฟล์ vgsales เช็คข้อมูลเบื้องต้น

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("vgsales.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### 2. สุ่มอ่านข้อมูล 10 แถว หัว 5 แถว และท้าย 10 แถว

# %%
df.sample(10)
# Out:
#         Rank                                            Name Platform    Year  \
# 1652    1654                                   Fuzion Frenzy       XB  2001.0
# 5873    5875                                           Jonas       DS  2009.0
# 6528    6530                         Evolution Skateboarding      PS2  2002.0
# 12962  12964                                Cities in Motion       PC  2011.0
# 9689    9691                          Obscure: The Aftermath      Wii  2008.0
# 6633    6635                                 Game of Thrones      PS3  2012.0
# 16297  16300                   Rakushou! Pachi-Slot Sengen 4      PS2  2006.0
# 10306  10308                          Murdered: Soul Suspect     X360  2014.0
# 4426    4428  The Urbz: Sims in the City (all regions sales)       DS  2004.0
# 6336    6338                                Bratz: The Movie      Wii  2007.0
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %% [markdown]
# ### 3. หา Top 10 Platform ยอดฮิต พร้อมระบุจำนวน

# %%
df2 = df.groupby('Platform').count()
df2_sort = df2.sort_values('Rank', ascending = False)
df2_sort['Rank'].head(10)
# Out:
# Platform
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# Name: Rank, dtype: int64

# %% [markdown]
# ### 4. หา Bottom 10 Platform ยอดฮิต พร้อมระบุจำนวน

# %%
df2_sort['Rank'].tail(10)[::-1]
# Out:
# Platform
# GG       1
# PCFX     1
# TG16     2
# 3DO      3
# WS       6
# SCD      6
# NG      12
# GEN     27
# DC      52
# GB      98
# Name: Rank, dtype: int64

# %% [markdown]
# ### 5. หา Top 10 Platform ชนิดของเกมส์ยอดฮิต พร้อมระบุจำนวน

# %%
# 10 ชนิดเกมส์ยอดฮิต? ไม่เข้าใจโจทย์ครับ
df2 = df.groupby('Genre').count()
df2_sort = df2.sort_values('Rank', ascending = False)
df2_sort['Rank'].head(10)
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Name: Rank, dtype: int64

# %% [markdown]
# ### 6. หา Bottom 10 Platform ชนิดของเกมส์ยอดฮิต พร้อมระบุจำนวน

# %%
df2_sort['Rank'].tail(10)[::-1]
# Out:
# Genre
# Puzzle           582
# Strategy         681
# Fighting         848
# Simulation       867
# Platform         886
# Racing          1249
# Adventure       1286
# Shooter         1310
# Role-Playing    1488
# Misc            1739
# Name: Rank, dtype: int64

# %% [markdown]
# ### 7. หารายละเอียดเกมส์ GTA V ภาคต่างๆ ทั้งหมด

# %%
df[df['Name'].str.contains("Grand Theft Auto V")]
# Out:
#       Rank                                               Name Platform  \
# 16      17                                 Grand Theft Auto V      PS3
# 23      24                                 Grand Theft Auto V     X360
# 44      45                                 Grand Theft Auto V      PS4
# 197    198                                 Grand Theft Auto V     XOne
# 617    618  Rockstar Games Double Pack: Grand Theft Auto I...       XB
# 1032  1034  Rockstar Games Double Pack: Grand Theft Auto I...      PS2
# 1896  1898                                 Grand Theft Auto V       PC
#
#         Year   Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16    2013.0  Action  Take-Two Interactive      7.01      9.27      0.97
# 23    2013.0  Action  Take-Two Interactive      9.63      5.31      0.06
# 44    2014.0  Action  Take-Two Interactive      3.80      5.81      0.36
# 197   2014.0  Action  Take-Two Interactive      2.66      2.01      0.00
# ...

# %% [markdown]
# ### 8. หาจำนวนเกมส์ที่มีชื่อซ้ำกันทั้งหมด

# %%
df2 = df.groupby('Name').count()
df2[df2['Rank']>1]["Rank"]
# Out:
# Name
# 007: Quantum of Solace              6
# 007: The World is not Enough        2
# 11eyes: CrossOver                   2
# 18 Wheeler: American Pro Trucker    2
# 187: Ride or Die                    2
#                                    ..
# iCarly                              2
# iCarly 2: iJoin The Click!          2
# nail'd                              2
# pro evolution soccer 2011           6
# uDraw Studio: Instant Artist        2
# Name: Rank, Length: 2775, dtype: int64

# %% [markdown]
# ### 9. หาจำนวนเกมส์ที่มีชื่อและ Platform ซ้ำกันทั้งหมด

# %%
df2 = df.groupby(['Name','Platform']).count()
df2[df2['Rank'] > 1]['Rank']
# Out:
# Name                         Platform
# Madden NFL 13                PS3         2
# Need for Speed: Most Wanted  PC          2
#                              X360        2
# Sonic the Hedgehog           PS3         2
# Wii de Asobu: Metroid Prime  Wii         2
# Name: Rank, dtype: int64

# %% [markdown]
# ### 10. จากข้อ 9 พิจารณาแถวที่ข้อมูลซ้ำและลบแถวนั้น

# %%
df[df.duplicated(['Name','Platform'])]
# Out:
#         Rank                         Name Platform    Year     Genre  \
# 1530    1532  Need for Speed: Most Wanted     X360  2005.0    Racing
# 4145    4147           Sonic the Hedgehog      PS3     NaN  Platform
# 11676  11678  Need for Speed: Most Wanted       PC  2012.0    Racing
# 14999  15002  Wii de Asobu: Metroid Prime      Wii     NaN   Shooter
# 16127  16130                Madden NFL 13      PS3  2012.0    Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1530   Electronic Arts       1.0      0.17      0.02         0.10
# 4145               NaN       0.0      0.48      0.00         0.00
# 11676  Electronic Arts       0.0      0.06      0.00         0.02
# 14999         Nintendo       0.0      0.00      0.02         0.00
# 16127  Electronic Arts       0.0      0.01      0.00         0.00
#
#        Global_Sales
# 1530           1.29
# 4145           0.48
# 11676          0.08
# 14999          0.02
# 16127          0.01

# %%
df.drop_duplicates(['Name','Platform'], inplace=True)

# %% [markdown]
# ### 11. หารายได้ทั้งหมดเกมส์ FIFA 15

# %%
df[df['Name'] == 'FIFA 15']['Global_Sales'].sum()
# Out:
# 19.020000000000003

# %% [markdown]
# ### 12. หารายได้ทั้งหมดของเกมส์ GTA V ในญี่ปุ่น

# %%
df[df['Name'].str.contains("Grand Theft Auto V")]['JP_Sales'].sum()
# Out:
# 1.3900000000000001

# %% [markdown]
# ### 13. สร้าง DF ที่ให้ index เป็นรายชื่อของเกมส์ที่มีซ้ำ และ Column เป็นจำนวนที่มีซ้ำ ไม่นับที่เป็น Unique

# %%
df2 = df.groupby('Name').count()
df3 = df2[df2['Rank'] > 1]['Rank']
df_new = pd.DataFrame(data = df3, index = df3.index)
df_new.rename(columns ={'Rank':'Count'}, inplace = True)
df_new
# Out:
#                                   Count
# Name
# 007: Quantum of Solace                6
# 007: The World is not Enough          2
# 11eyes: CrossOver                     2
# 18 Wheeler: American Pro Trucker      2
# 187: Ride or Die                      2
# ...                                 ...
# iCarly                                2
# iCarly 2: iJoin The Click!            2
# nail'd                                2
# pro evolution soccer 2011             6
# uDraw Studio: Instant Artist          2
#
# [2774 rows x 1 columns]

# %% [markdown]
# ### 14. สร้าง DF ที่มี index เป็นชื่อบริษัท และเรียงลำดับตามรายได้รวมจากมากไปน้อย

# %%
df2 = df.groupby('Publisher').sum()
df3 = df2.sort_values('Global_Sales')[::-1]['Global_Sales']
df_new = pd.DataFrame(data = df3, index = df3.index)
df_new
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1786.54
# Electronic Arts                   1108.94
# Activision                         727.46
# Sony Computer Entertainment        607.50
# Ubisoft                            474.72
# ...                                   ...
# Takuyo                               0.01
# Otomate                              0.01
# Epic Games                           0.01
# Inti Creates                         0.01
# Interworks Unlimited, Inc.           0.01
#
# [578 rows x 1 columns]

# %% [markdown]
# ### 15. จงสร้าง DF ที่บรรจุเกมส์ Series Call of duty ทั้งหมด

# %%
df2 = df[df['Name'].str.contains("Call of Duty")]
df2.head()
# Out:
#     Rank                            Name Platform    Year    Genre  \
# 29    30  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31    32         Call of Duty: Black Ops     X360  2010.0  Shooter
# 33    34       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 34    35      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 35    36      Call of Duty: Black Ops II     X360  2012.0  Shooter
#
#      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 29  Activision      9.03      4.28      0.13         1.32         14.76
# 31  Activision      9.67      3.73      0.11         1.13         14.64
# 33  Activision      5.77      5.81      0.35         2.31         14.24
# 34  Activision      4.99      5.88      0.65         2.52         14.03
# 35  Activision      8.25      4.30      0.07         1.12         13.73

# %% [markdown]
# ### 16. จงหาว่า Call of Duty ภาคใดใน PC มีรายสูงสุดในยุโรป 5 อันดับแรก

# %%
df2[df2['Platform'] == 'PC'].sort_values('EU_Sales')[::-1].head(5)
# Out:
#       Rank                            Name Platform    Year    Genre  \
# 1769  1771  Call of Duty 4: Modern Warfare       PC  2007.0  Shooter
# 1037  1039  Call of Duty: Modern Warfare 3       PC  2011.0  Shooter
# 1126  1128         Call of Duty: Black Ops       PC     NaN  Shooter
# 2347  2349  Call of Duty: Modern Warfare 2       PC  2009.0  Shooter
# 1217  1219      Call of Duty: Black Ops II       PC  2012.0  Shooter
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1769  Activision      0.00      1.12       0.0         0.03          1.15
# 1037  Activision      0.41      0.98       0.0         0.33          1.72
# 1126  Activision      0.58      0.81       0.0         0.24          1.63
# 2347  Activision      0.01      0.79       0.0         0.09          0.89
# 1217  Activision      0.63      0.69       0.0         0.21          1.53

# %% [markdown]
# ### 17. จงหาว่า Platform ใด มียอดขายรวมสูงสุดในยุโรป

# %%
df.groupby('Platform').sum().sort_values('EU_Sales')[::-1].head(1)
# Out:
#              Rank       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# PS3       9007693  2620097.0    392.26    343.22     79.99       141.93
#
#           Global_Sales
# Platform
# PS3             957.35

# %% [markdown]
# ### 18. จงหาว่าเกมส์ประเภทใดมียอดขายเฉลี่ยสูงสุดในภูมิภาคอื่นๆรอบโลก

# %%
df.groupby('Genre').mean().sort_values('Other_Sales')[::-1]
# Out:
#                       Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Shooter        7363.537051  2005.918877  0.445073  0.239320  0.029228
# Racing         7963.691259  2004.834150  0.287426  0.190986  0.045445
# Platform       6930.393220  2003.820776  0.505141  0.227288  0.147763
# Sports         7421.314286  2005.475033  0.291407  0.160699  0.057727
# Action         7973.879071  2007.909929  0.264726  0.158323  0.048236
# Misc           8561.847039  2007.258480  0.235906  0.124198  0.061967
# Fighting       7646.511792  2004.630383  0.263667  0.119481  0.103007
# Role-Playing   8086.174731  2007.055744  0.219946  0.126384  0.236767
# Simulation     8626.085352  2006.567568  0.211430  0.130773  0.073472
# Puzzle         9627.381443  2005.243433  0.212680  0.087251  0.098471
# Strategy      10071.897210  2005.599106  0.100881  0.066579  0.072628
# Adventure     11532.787714  2008.130878  0.082271  0.049868  0.040490
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %% [markdown]
# ### 19. สร้าง Bar Plot โดยให้แกน X เป็น Platform และ Y เป็นยอดขายทั่วโลก

# %%
fig = plt.figure(figsize = (12,10))
sns.barplot(x = 'Platform', y = 'Global_Sales', data = df)

# %% [markdown]
# ### 20. สร้าง Pie Chart หาส่วนแบ่งทางการตลาดของ 5 บริษัทแรกที่มีรายได้มากที่สุด

# %%
df2 = df.groupby('Publisher').sum().sort_values('Global_Sales')[::-1].head(5)
df2
plt.pie(df2['Global_Sales'], labels = df2.index)
plt.show()

# %% [markdown]
# ### 21. สร้าง Count Plot นับข้อมูลประเภทของเกมส์

# %%
fig = plt.figure(figsize = (8,5))
sns.countplot(df["Genre"])
fig.autofmt_xdate()

# %% [markdown]
# ### 22. สร้าง Bar plot Top 5 รายได้ทั่วโลกของ Call of Duty ภาคต่างๆใน Xbox

# %%
df2 = df[df['Name'].str.contains("Call of Duty")]
df2[df2['Platform'] == 'X360']['Global_Sales'].sum()
# Out:
# 94.41999999999999

# %% [markdown]
# ### 23. สร้าง Line Graph แสดงรายได้จาก North America จากปีแรกถึงปีสุดท้าย

# %%
df2 = df.groupby('Year').sum()
sns.lineplot(x = df2.index, y = 'NA_Sales', data = df2)
plt.show()

# %% [markdown]
# ### 24. สร้าง Stripplot โดยให้แกน X เป็น Genre และ แกน Y เป็นรายได้ทั่วโลก

# %%
fig = plt.figure(figsize = (12,6))
sns.stripplot(x = 'Genre', y = 'Global_Sales', data = df)

# %% [markdown]
# ### 25. สร้าง Distribution Plot ของปี

# %%
df['Year'].dropna(inplace= True)
sns.distplot(df['Year'])

# %% [markdown]
# ### 26. สร้าง Bar Plot แสดงรายได้รวมในญี่ปุ่นรายปี

# %%
df2 = df.groupby('Year').sum()
fig = plt.figure(figsize = (16,10))
sns.barplot(x = df2.index, y = 'JP_Sales', data = df2)
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ## 2.วิเคราะห์ข้อมูลจากการจองที่พักผ่าน Airbnb ที่ New York

# %% [markdown]
# ### 1. Import ไฟล์ AB_NYC_2019 และ เช็คข้อมูลเบื้องต้น

# %%
df = pd.read_csv('AB_NYC_2019.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48879 non-null object
# host_id                           48895 non-null int64
# host_name                         48874 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# ...

# %% [markdown]
# ### 2. สุ่มอ่านข้อมูล 10 แถว หัว 5 แถว และท้าย 10 แถว

# %%
df.sample(10)
# Out:
#              id                                               name    host_id  \
# 974      389482                           Quaint & Quiet in Queens    1947974
# 42107  32695800                Thanksgiving - New York City (A144)  244746656
# 40545  31435825      Lovely 2BR, 2BATH in heart of East Village!!!  235468713
# 35614  28282908      Industrial-Chic Room Available in Artist Loft   49218771
# 37985  30021086  Room in a Cosy Appartment, Midtown, Grand Central   92963604
# 24871  19945772          Kensington/Ditmas Park Single family home   16532782
# 29684  22796694                      room 3 Manhattan private room  164886138
# 2877    1645196          Park Slope 1BR with Private Outdoor Space    4623045
# 40958  31861671     Hamilton Loft. 2Queen. priv bath. full kitchen  238750007
# 40043  31097777  Quiet One-Bedroom in Williamsburg Close to Subway  115064362
#
#           host_name neighbourhood_group neighbourhood  latitude  longitude  \
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail(10)
# Out:
#              id                                               name    host_id  \
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %% [markdown]
# ### 3. หา Top 10 Neighbourhood ยอดฮิต พร้อมระบุจำนวน

# %%
df2 = df.groupby('neighbourhood').count()
df2_sort = df2.sort_values('id', ascending = False)
df2_sort['id'].head(10)
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: id, dtype: int64

# %% [markdown]
# ### 4. หา Bottom 10 Neighbourhood ยอดฮิต พร้อมระบุจำนวน

# %%
df2_sort['id'].tail(10)[::-1]
# Out:
# neighbourhood
# Woodrow                       1
# New Dorp                      1
# Fort Wadsworth                1
# Willowbrook                   1
# Richmondtown                  1
# Rossville                     1
# Silver Lake                   2
# Lighthouse Hill               2
# West Farms                    2
# Bay Terrace, Staten Island    2
# Name: id, dtype: int64

# %% [markdown]
# ### 5. หา Top 10 Neighbourhood Group ยอดฮิต พร้อมระบุจำนวน

# %%
df2 = df.groupby('neighbourhood_group').count()
df2_sort = df2.sort_values('id', ascending = False)
df2_sort['id'].head(10)
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: id, dtype: int64

# %% [markdown]
# ### 6. หา Bottom 10 Neighbourhood Group ยอดฮิต พร้อมระบุจำนวน

# %%
df2_sort['id'].tail(10)[::-1]
# Out:
# neighbourhood_group
# Staten Island      373
# Bronx             1091
# Queens            5666
# Brooklyn         20104
# Manhattan        21661
# Name: id, dtype: int64

# %% [markdown]
# ### 7. หาค่าเฉลี่ยราคาของพื้นที่ และเขต

# %%
df2 = df.groupby(['neighbourhood_group','neighbourhood']).mean()
df2[['id','price']]
# Out:
#                                              id       price
# neighbourhood_group neighbourhood
# Bronx               Allerton       2.007729e+07   87.595238
#                     Baychester     2.215566e+07   75.428571
#                     Belmont        2.690317e+07   77.125000
#                     Bronxdale      2.190473e+07   57.105263
#                     Castle Hill    3.304754e+07   63.000000
# ...                                         ...         ...
# Staten Island       Tottenville    1.823501e+07  144.857143
#                     West Brighton  1.885742e+07   80.555556
#                     Westerleigh    2.070684e+07   71.500000
#                     Willowbrook    2.708802e+07  249.000000
#                     Woodrow        1.798271e+06  700.000000
#
# [221 rows x 2 columns]

# %% [markdown]
# ### 8. จงหาว่าห้องประเภทใดมีราคาเฉลี่ยมากที่สุด

# %%
df2 = df.groupby('room_type').mean()
df2[['id','price']]
# Out:
#                            id       price
# room_type
# Entire home/apt  1.843818e+07  211.794246
# Private room     1.946893e+07   89.780973
# Shared room      2.300378e+07   70.127586

# %% [markdown]
# ### 9. จงหาว่าพื้นที่ใดมีข้อมูลพื้นที่อยู่แค่หน่วยเดียว

# %%
df2 = df.groupby('neighbourhood').count()
df2[df2['id'] == 1]['id']
# Out:
# neighbourhood
# Fort Wadsworth    1
# New Dorp          1
# Richmondtown      1
# Rossville         1
# Willowbrook       1
# Woodrow           1
# Name: id, dtype: int64

# %% [markdown]
# ### 10. จงหาว่าที่พักแบบใดมีการให้บริการมากที่สุด และมากเท่าใด

# %%
df2 = df.groupby('room_type').count()
df2[['id','price']]
# Out:
#                     id  price
# room_type
# Entire home/apt  25409  25409
# Private room     22326  22326
# Shared room       1160   1160

# %% [markdown]
# ### 11. จงหาว่าพื้นที่ใดมีจำนวนรีวิวมากที่สุด และ เขตใดมีจำนวนรีวิวมากที่สุด

# %%
df2 = df.groupby(['neighbourhood_group','neighbourhood']).sum()
df2_sort = df2.sort_values('number_of_reviews', ascending = False)
df2[['id','number_of_reviews']]
# Out:
#                                           id  number_of_reviews
# neighbourhood_group neighbourhood
# Bronx               Allerton       843246032               1803
#                     Baychester     155089630                310
#                     Belmont        645675967                296
#                     Bronxdale      416189922                458
#                     Castle Hill    297427859                118
# ...                                      ...                ...
# Staten Island       Tottenville    127645045                139
#                     West Brighton  339433507                656
#                     Westerleigh     41413683                 18
#                     Willowbrook     27088022                  9
#                     Woodrow          1798271                  0
#
# [221 rows x 2 columns]

# %% [markdown]
# ### 12. จงหา Top 3 จำนวน Minimum Nights ที่มีเขตไม่ซ้ำกัน

# %%
df2 = df.sort_values('minimum_nights')[::-1]
df2.drop_duplicates('neighbourhood_group',inplace =True)
df2.nlargest(columns= 'minimum_nights',n =3)
# Out:
#              id                                 name    host_id  host_name  \
# 5767    4204302     Prime W. Village location 1 bdrm   17550546  Genevieve
# 26341  20990053      Beautiful place in Brooklyn! #2  151084261      Angie
# 7355    5431845  Beautiful Fully Furnished 1 bed/bth    3680008      Aliya
#
#       neighbourhood_group      neighbourhood  latitude  longitude  \
# 5767            Manhattan  Greenwich Village  40.73293  -73.99782
# 26341            Brooklyn       Williamsburg  40.71772  -73.95059
# 7355               Queens   Long Island City  40.75104  -73.93863
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 5767   Entire home/apt    180            1250                  2  2014-11-09
# 26341     Private room     79             999                 24  2018-06-28
# 7355   Entire home/apt    134             500                 30  2018-06-24
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ### 13. จงหาชื่อ Host ที่ลิสที่อยู่มากที่สุด 10 อันดับแรก (Hint: ใช้ชื่อไม่ได้)

# %%
df2 = df.groupby('host_id').sum()
x = df2.nlargest(columns= 'calculated_host_listings_count',n =10).index
y = df[df['host_id'].isin(x)].drop_duplicates('host_id')
y.sort_values('calculated_host_listings_count')[::-1]
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 26137  20845031  Homey Midtown East 1BR w/ Gym, Doorman, near t...  107434423
# 9740    7491713       NYC Lavish Studio Apartment Steps from SoHo!   30283594
# 32718  25779464              Lovely Room in the Heart of Manhattan  137358866
# 30637  23702074          Sonder | 180 Water | Lovely 1BR + Rooftop   12243051
# 5093    3662724                 5144-Prime Doorman!78ST & Madison    16098958
# 14682  11602050                     Museum Mile 1 BR - Madison Ave   61391963
# 15865  12832371  East 74th street, Cozy UES 1bd Serviced Apartment   22541573
# 34010  26945421       STUDIO ON WEST 56TH COLUMBUS CIRCLE~ DOORMAN  200380610
# 1386     613556                2 BED TriBeCa, Beautiful-Renovated!    1475015
#
#                host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %% [markdown]
# ### 14. จงหาชื่อ Host ที่มีชื่อซ้ำกันมากที่สุด 10 ชื่อ (โดยที่ไม่ใช้คนเดียวกัน)

# %%
df2 = df.drop_duplicates('host_id')
df2.groupby('host_name').count().sort_values('name')[::-1]['name'][0:10]
# Out:
# host_name
# Michael    335
# David      318
# Alex       226
# Daniel     208
# Sarah      199
# John       188
# Andrew     163
# Chris      162
# Maria      161
# Anna       155
# Name: name, dtype: int64

# %% [markdown]
# ### 15. จงหาชื่อ Host ที่มีรีวิวมากที่สุด 10 อันดับแรก

# %%
df.groupby('host_name').sum().nlargest(columns ='number_of_reviews', n = 10)
# Out:
#                    id      host_id     latitude    longitude  price  \
# host_name
# Michael    5773680495  16965075350  13644.26597 -24777.02875  56178
# David      5759743425  19466507156  12951.88914 -23518.72322  53038
# John       3297832378  11264735952   7657.61985 -13904.25451  30300
# Alex       4451567844  17286596410   9204.19158 -16715.94351  46784
# Chris      2598732831   7796877771   6598.08636 -11981.22658  24502
# Daniel     3570192183   9130483388   8471.96475 -15383.32393  30744
# Sarah      3045653375   7335143901   8103.95284 -14717.40256  26566
# Jason      1680319316   5448607438   4194.54345  -7618.02595  16218
# Eric       1824146748   4546131092   4683.74316  -8505.29171  18366
# Michelle   1843309666   5801038761   4887.15626  -8874.87849  17581
#
#            minimum_nights  number_of_reviews  reviews_per_month  \
# host_name
# Michael              2048               8566             346.19
# David                2716               6830             340.75
# ...

# %% [markdown]
# ### 16. จงหาชื่อ Host ที่มีการลิสที่อยู่ที่มีราคาเฉลี่ยสูงที่สุด 10 อันดับแรก

# %%
df.groupby('host_name').mean().nlargest(columns ='price', n = 10)
# Out:
#                            id       host_id   latitude  longitude  \
# host_name
# Olson            4.737930e+06  1.235070e+06  40.792640 -73.938980
# Rum              2.337741e+07  1.812846e+07  40.721970 -74.006330
# Jay And Liz      2.110145e+06  2.151325e+06  40.777820 -73.978480
# Sarah-2          2.065423e+07  1.000690e+08  40.681850 -73.881280
# Sarah-B          2.123805e+07  1.534978e+08  40.687420 -73.919570
# Nony             3.498164e+07  2.635642e+08  40.630870 -74.020060
# Kathrine         3.516581e+06  9.072024e+06  40.733010 -73.957017
# Jelena           2.203596e+07  4.430071e+07  40.715897 -73.978340
# Luxury Property  3.014641e+07  1.010802e+08  40.736520 -73.986180
# Rogelio          3.618920e+07  2.702140e+08  40.755330 -73.998660
#
#                        price  minimum_nights  number_of_reviews  \
# host_name
# Olson            9999.000000        5.000000           1.000000
# Rum              8500.000000       30.000000           2.000000
# ...

# %% [markdown]
# ### 17. จงเพิ่ม 2 คอลัมน์ชื่อ Year และ Month จาก last review ต่อท้าย โดยใช้ข้อมูลจากคอลัมน์ last_review (Hint: ใช้ lambda)

# %%
df.dropna(inplace=True)
df[['Year','Month','Day']] = df['last_review'].str.split('-',expand=True)
df
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %% [markdown]
# ### 18. สร้างคอลัมน์ใหม่ โดยให้บรรจุ Day-of-the-week (Mon, Tue....) โดยใช้ข้อมูลจาก last_review (Hint: ใช้ datetime กับ map มาช่วย) กำหนดให้ 0 = Mon, 1= Tue, 2 = Wed, 3 = Thu, 4 = Fri, 5 = Sat, 6 = Sun

# %%
df['last_review'] = pd.to_datetime(df['last_review'])
df['day_of_week'] = df['last_review'].dt.dayofweek
df
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %% [markdown]
# ### 19. สร้าง Count Plot นับข้อมูลประเภทของที่อยู่อาศัย

# %%
sns.countplot(df['room_type'])

# %% [markdown]
# ### 20. สร้าง Pie Chart หาพื้นที่ ที่มีที่อยู่อาศัยเยอะที่สุด 5 อันดับแรก

# %%
s = df.groupby('neighbourhood').count().nlargest(columns = 'id', n = 5)
plt.pie(s['id'], labels = s.index)
plt.show()

# %% [markdown]
# ### 21. สร้าง Box Plot โดยให้แกน X เป็น เขต และ Y เป็นจำนวนรีวิว

# %%
fig = plt.figure(figsize = (15,10))
sns.boxplot(x = 'neighbourhood_group', y = 'number_of_reviews', data =df)

# %% [markdown]
# ### 22. สร้าง HeatMap จาก Correlation ของ DataFrame และพิจารณาดูความสัมพันธ์ พร้อมกับนำความสัมพันธ์ที่เป็น Strongest Positive มาทำ Scatter Plot

# %%
s = df.corr()
fig = plt.figure(figsize = (12,8))
sns.heatmap(s ,cmap = 'coolwarm')

# %%
s
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.591480 -0.010085   0.103336
# host_id                         0.591480  1.000000  0.012823   0.141276
# latitude                       -0.010085  0.012823  1.000000   0.088259
# longitude                       0.103336  0.141276  0.088259   1.000000
# price                          -0.006696  0.006263  0.031344  -0.155298
# minimum_nights                 -0.073937 -0.051673  0.024893  -0.055414
# number_of_reviews              -0.330019 -0.141973 -0.008559   0.054746
# reviews_per_month               0.291786  0.296274 -0.010117   0.146228
# calculated_host_listings_count  0.098446  0.149417  0.004340  -0.093348
# availability_365                0.006624  0.155361 -0.021921   0.102573
# day_of_week                     0.028229  0.029273  0.000071   0.016764
#
#                                    price  minimum_nights  number_of_reviews  \
# ...

# %%
sns.scatterplot(x= 'number_of_reviews', y ='availability_365', data= df)

# %% [markdown]
# ### 23. สร้าง Count plot หาจำนวน Last review ของแต่ละเดือนของปี 2018

# %%
s = df[df['Year']=='2018']
s.groupby('Month').count()['last_review']
# Out:
# Month
# 01    554
# 02    142
# 03    209
# 04    313
# 05    401
# 06    382
# 07    506
# 08    686
# 09    635
# 10    714
# 11    560
# 12    945
# Name: last_review, dtype: int64

# %% [markdown]
# ### 24. สร้าง Pie Chart หาอัตราส่วน Last Review ในแต่ละวัน

# %%
s = df.groupby('day_of_week').count()
plt.pie(s['id'], labels = ['Mon',  'Tue',  'Wed', 'Thu', 'Fri',  'Sat', 'Sun'])
plt.show()

# %% [markdown]
# ### 25. สร้าง Line Graph หาราคาเฉลี่ยในแต่ละเดือนของ Last Review ในปี 2019

# %%
s = df[df['Year']=='2019']
s.groupby('Month').mean()['price']
# Out:
# Month
# 01    140.584840
# 02    145.612766
# 03    136.243902
# 04    143.211538
# 05    139.540855
# 06    141.621240
# 07    144.506565
# Name: price, dtype: float64

# %% [markdown]
# ### 26. สร้าง Column ใหม่ โดยคำนวณ ณ เวลาปัจจุบันถึงวันที่ Last Review ห่างกันกี่วัน (Hint: ใช้ datetime ปัจจุบัน - datetime last review)

# %%
df['duration'] = pd.to_datetime("today") - pd.to_datetime(df['last_review'])
df
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %% [markdown]
# ### 27. สร้าง Pie Chart ของระยะห่างของเวลา ระหว่างปัจจุบันถึง Last review เฉลี่ย ของแต่ละเขต (หน่วยเป็นวัน)

# %%
df['duration'] = df['duration'].astype('int16')
s = df.groupby('neighbourhood_group').mean()
plt.pie(s['duration'], labels = s.index)
plt.show()

# %% [markdown]
# ### 28. สร้าง Bar Plot ของระยะห่างของเวลา ระหว่างปัจจุบันถึง Last review เฉลี่ย ของแต่ละพื้นที่ 10 พื้นที่แรกที่มีระยะเวลามากที่สุด (หน่วยเป็นวัน)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0     Private room    149  ...                  9   2018-10-19
# ...

# %%
s = df.groupby('neighbourhood').mean().nlargest(columns = 'duration', n = 10)
fig = plt.figure(figsize= (15,10))
sns.barplot(x = s.index, y= 'duration' , data = s)
fig.autofmt_xdate()

# %% [markdown]
# ### 29. สร้าง Bar Plot ของค่าเฉลี่ยระยะเวลาห่างระหว่างปัจจุบันถึง Last review เฉลี่ย ของแต่ละพื้นที่ 10 พื้นที่แรกที่มีระยะเวลาน้อยที่สุด

# %%
s = df.groupby('neighbourhood').mean().nsmallest(columns = 'duration', n = 10)
fig = plt.figure(figsize= (15,10))
sns.barplot(x = s.index, y= 'duration' , data = s)
fig.autofmt_xdate()

# %% [markdown]
# ### 30. สร้าง Scatter Plot หาความสัมพันธ์ระหว่าง ระยะเวลาห่างระหว่างปัจจุบันถึง Last review กับ Minimum Nights (Hint: Correlation)

# %%
s = df.corr()
s
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.591480 -0.010085   0.103336
# host_id                         0.591480  1.000000  0.012823   0.141276
# latitude                       -0.010085  0.012823  1.000000   0.088259
# longitude                       0.103336  0.141276  0.088259   1.000000
# price                          -0.006696  0.006263  0.031344  -0.155298
# minimum_nights                 -0.073937 -0.051673  0.024893  -0.055414
# number_of_reviews              -0.330019 -0.141973 -0.008559   0.054746
# reviews_per_month               0.291786  0.296274 -0.010117   0.146228
# calculated_host_listings_count  0.098446  0.149417  0.004340  -0.093348
# availability_365                0.006624  0.155361 -0.021921   0.102573
# day_of_week                     0.028229  0.029273  0.000071   0.016764
# duration                       -0.414165 -0.270930  0.021806  -0.105603
#
# ...

# %%
fig = plt.figure(figsize= (15,8))
sns.scatterplot(x = 'duration', y = 'minimum_nights', data =df)
